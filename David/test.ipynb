# %%
import sys

class Resource:
    """
    Represents a single resource definition (from the R lines in input).
    """
    def __init__(self, RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr):
        self.RI = RIr  # Resource ID
        self.RA = RAr  # Activation cost
        self.RP = RPr  # Periodic (maintenance) cost
        self.RW = RWr  # Number of consecutive active turns
        self.RM = RMr  # Number of downtime turns required after active cycle
        self.RL = RLr  # Total life in turns
        self.RU = RUr  # Buildings powered when active
        self.RT = RTr  # Special effect type
        self.RE = REr  # Special effect percentage or capacity

class Turn:
    """
    Represents a single turn's constraints: min building (TM), max building (TX), profit per building (TR).
    """
    def __init__(self, TM, TX, TR):
        self.TM = TM
        self.TX = TX
        self.TR = TR

class PurchasedResource:
    """
    Represents a resource instance that has been purchased, tracking where it is in its
    active/downtime life cycle.
    """
    def __init__(self, resource_index, life_left, active_left, downtime_left):
        self.resource_index = resource_index  # index into the 'resources' list
        self.life_left = life_left
        self.active_left = active_left
        self.downtime_left = downtime_left

class GreenRevolutionGame:
    """
    Manages all data (budget, resources, turns), runs the simulation turn by turn,
    and decides which resources to purchase (naively).
    """
    def __init__(self, data):
        # data is the list of tokens read from input
        self.parse_input(data)
        self.budget = self.D
        self.purchased_resources = []  # list of PurchasedResource
        self.output_lines = []         # lines to write into output.txt

    def parse_input(self, data):
        idx = 0
        # First line: D, R, T
        self.D = int(data[idx]); idx += 1
        self.R = int(data[idx]); idx += 1
        self.T = int(data[idx]); idx += 1

        self.resources = []
        for _ in range(self.R):
            RIr = int(data[idx]); idx += 1
            RAr = int(data[idx]); idx += 1
            RPr = int(data[idx]); idx += 1
            RWr = int(data[idx]); idx += 1
            RMr = int(data[idx]); idx += 1
            RLr = int(data[idx]); idx += 1
            RUr = int(data[idx]); idx += 1

            RTr = data[idx];      idx += 1
            if RTr in ['A', 'B', 'C', 'D', 'E']:
                REr = int(data[idx])
                idx += 1
            else:
                REr = 0

            self.resources.append(Resource(RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr))

        self.turns = []
        for _ in range(self.T):
            TMt = int(data[idx]); idx += 1
            TXt = int(data[idx]); idx += 1
            TRt = int(data[idx]); idx += 1
            self.turns.append(Turn(TMt, TXt, TRt))

    def decide_which_resource_to_buy(self):
        """
        Naive: picks a single resource with the best RU/(RA+RP) ratio,
        if affordable. Returns its index in self.resources, or None if none is affordable.
        """
        best_idx = None
        best_score = -1.0

        for i, r in enumerate(self.resources):
            if r.RA <= self.budget:
                cost = float(r.RA + r.RP) if (r.RP > 0) else float(r.RA)
                ratio = float(r.RU) / cost if cost > 0 else r.RU
                if ratio > best_score:
                    best_score = ratio
                    best_idx = i
        return best_idx

    def run(self):
        """
        Simulate the T turns. On each turn:
          1) Possibly buy resources (if affordable).
          2) Pay maintenance costs.
          3) Compute powered buildings, check if >= TM => compute profit.
          4) Update budget, reduce lifecycles, remove obsolete resources.
        """
        for turn_idx in range(self.T):
            turn_data = self.turns[turn_idx]

            # -- 1) Purchase Phase (naive) --
            chosen_idx = self.decide_which_resource_to_buy()
            if chosen_idx is not None:
                cost_needed = self.resources[chosen_idx].RA
                if cost_needed <= self.budget:
                    # Buy this resource
                    self.budget -= cost_needed
                    r = self.resources[chosen_idx]
                    # Add a new purchased resource
                    self.purchased_resources.append(
                        PurchasedResource(
                            resource_index=chosen_idx,
                            life_left=r.RL,
                            active_left=r.RW,
                            downtime_left=0
                        )
                    )
                    # Record in output
                    line = f"{turn_idx} 1 {r.RI}"
                    self.output_lines.append(line)

            # -- 2) Pay maintenance + track total powered buildings --
            maintenance_cost = 0
            powered_buildings = 0

            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    # Maintenance cost
                    r_idx = pr.resource_index
                    maintenance_cost += self.resources[r_idx].RP
                    # If in active phase, add RU
                    if pr.active_left > 0:
                        powered_buildings += self.resources[r_idx].RU

            # Subtract maintenance cost from budget
            self.budget -= maintenance_cost

            # -- 3) Compute profit (if TM is met) --
            if powered_buildings >= turn_data.TM:
                profit = min(powered_buildings, turn_data.TX) * turn_data.TR
            else:
                profit = 0

            # Update budget
            self.budget += profit

            # -- 4) Decrement resource lifecycles --
            new_purchases = []
            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    # If active
                    if pr.active_left > 0:
                        pr.active_left -= 1
                        # If just ended active phase, set downtime
                        if pr.active_left == 0:
                            r_idx = pr.resource_index
                            pr.downtime_left = self.resources[r_idx].RM
                    else:
                        # In downtime
                        if pr.downtime_left > 0:
                            pr.downtime_left -= 1
                            if pr.downtime_left == 0:
                                r_idx = pr.resource_index
                                pr.active_left = self.resources[r_idx].RW

                    pr.life_left -= 1

            # Remove dead resources
            self.purchased_resources = [
                pr for pr in self.purchased_resources if pr.life_left > 0
            ]

    def write_output(self, filename="output.txt"):
        """
        Writes the recorded purchase lines to output.txt (or another file).
        Each line is "turn Rcount RI1 RI2 ..."
        (Here, we always buy at most 1 resource, so Rcount=1 or 0.)
        """
        with open(filename, "w") as f:
            for line in self.output_lines:
                f.write(line + "\n")

def solve():
    # Read data from stdin
    data = sys.stdin.read().strip().split()

    # Create a game instance
    game = GreenRevolutionGame(data)
    # Run the simulation
    game.run()
    # Write all purchases to "output.txt"
    game.write_output("output.txt")

# %%
class Resource:
    """
    Represents a single resource definition (from the R lines in input).
    """
    def __init__(self, RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr):
        self.RI = RIr  # Resource ID
        self.RA = RAr  # Activation cost
        self.RP = RPr  # Periodic (maintenance) cost
        self.RW = RWr  # Number of consecutive active turns
        self.RM = RMr  # Number of downtime turns required after active cycle
        self.RL = RLr  # Total life in turns
        self.RU = RUr  # Buildings powered when active
        self.RT = RTr  # Special effect type
        self.RE = REr  # Special effect parameter (percentage or capacity)


class Turn:
    """
    Represents a single turn's constraints: min building (TM), max building (TX), profit per building (TR).
    """
    def __init__(self, TM, TX, TR):
        self.TM = TM
        self.TX = TX
        self.TR = TR


class PurchasedResource:
    """
    Represents a resource instance that has been purchased, tracking where it is in its
    active/downtime life cycle.
    """
    def __init__(self, resource_index, life_left, active_left, downtime_left):
        self.resource_index = resource_index  # index into the 'resources' list
        self.life_left = life_left
        self.active_left = active_left
        self.downtime_left = downtime_left


class GreenRevolutionGame:
    """
    Manages all data (budget, resources, turns), runs the simulation turn by turn,
    and decides which resources to purchase (naively).
    """
    def __init__(self, data_tokens):
        # Parse the data from a list of tokens (strings).
        self.parse_input(data_tokens)
        self.budget = self.D
        self.purchased_resources = []  # list of PurchasedResource
        self.output_lines = []         # lines to write into output file

    def parse_input(self, data):
        idx = 0
        # First line: D, R, T
        self.D = int(data[idx]); idx += 1
        self.R = int(data[idx]); idx += 1
        self.T = int(data[idx]); idx += 1

        self.resources = []
        for _ in range(self.R):
            RIr = int(data[idx]); idx += 1
            RAr = int(data[idx]); idx += 1
            RPr = int(data[idx]); idx += 1
            RWr = int(data[idx]); idx += 1
            RMr = int(data[idx]); idx += 1
            RLr = int(data[idx]); idx += 1
            RUr = int(data[idx]); idx += 1

            RTr = data[idx];      idx += 1
            if RTr in ['A', 'B', 'C', 'D', 'E']:
                REr = int(data[idx])
                idx += 1
            else:
                REr = 0

            self.resources.append(Resource(RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr))

        self.turns = []
        for _ in range(self.T):
            TMt = int(data[idx]); idx += 1
            TXt = int(data[idx]); idx += 1
            TRt = int(data[idx]); idx += 1
            self.turns.append(Turn(TMt, TXt, TRt))

    def decide_which_resource_to_buy(self):
        """
        Naive: picks a single resource with the best RU/(RA+RP) ratio,
        if affordable. Returns its index in self.resources, or None if no resource is affordable.
        """
        best_idx = None
        best_score = -1.0

        for i, r in enumerate(self.resources):
            if r.RA <= self.budget:
                cost = float(r.RA + r.RP) if (r.RP > 0) else float(r.RA)
                ratio = float(r.RU) / cost if cost > 0 else r.RU
                if ratio > best_score:
                    best_score = ratio
                    best_idx = i
        return best_idx

    def run(self):
        """
        Simulate T turns. On each turn:
          1) Possibly buy resources (if affordable).
          2) Pay maintenance costs.
          3) Compute powered buildings, check if >= TM => compute profit.
          4) Update budget, reduce lifecycles, remove obsolete resources.
        """
        for turn_idx in range(self.T):
            turn_data = self.turns[turn_idx]

            # -- 1) Purchase Phase (naive) --
            chosen_idx = self.decide_which_resource_to_buy()
            if chosen_idx is not None:
                cost_needed = self.resources[chosen_idx].RA
                if cost_needed <= self.budget:
                    # Buy this resource
                    self.budget -= cost_needed
                    r = self.resources[chosen_idx]
                    # Add a new purchased resource
                    self.purchased_resources.append(
                        PurchasedResource(
                            resource_index=chosen_idx,
                            life_left=r.RL,
                            active_left=r.RW,
                            downtime_left=0
                        )
                    )
                    # Record purchase in output (turn, count=1, resourceID)
                    line = f"{turn_idx} 1 {r.RI}"
                    self.output_lines.append(line)

            # -- 2) Pay maintenance + track total powered buildings --
            maintenance_cost = 0
            powered_buildings = 0

            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    # Maintenance cost
                    r_idx = pr.resource_index
                    maintenance_cost += self.resources[r_idx].RP
                    # If in active phase, add RU
                    if pr.active_left > 0:
                        powered_buildings += self.resources[r_idx].RU

            # Subtract maintenance cost from budget
            self.budget -= maintenance_cost

            # -- 3) Compute profit (if TM is met) --
            if powered_buildings >= turn_data.TM:
                profit = min(powered_buildings, turn_data.TX) * turn_data.TR
            else:
                profit = 0

            # Update budget
            self.budget += profit

            # -- 4) Decrement resource lifecycles --
            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    # If active
                    if pr.active_left > 0:
                        pr.active_left -= 1
                        # If just ended active phase, set downtime
                        if pr.active_left == 0:
                            r_idx = pr.resource_index
                            pr.downtime_left = self.resources[r_idx].RM
                    else:
                        # In downtime
                        if pr.downtime_left > 0:
                            pr.downtime_left -= 1
                            if pr.downtime_left == 0:
                                r_idx = pr.resource_index
                                pr.active_left = self.resources[r_idx].RW

                    # Decrease total life
                    pr.life_left -= 1

            # Remove dead resources
            self.purchased_resources = [pr for pr in self.purchased_resources if pr.life_left > 0]

    def write_output(self, filename):
        """
        Writes the recorded purchase lines to the given file.
        Each line is "turn Rcount RI1 RI2 ...".
        """
        with open(filename, "w") as f:
            for line in self.output_lines:
                f.write(line + "\n")


def solve(input_filename="0-demo.txt", output_filename="output.txt"):
    """
    Reads all tokens from `input_filename`, runs the naive solver,
    and writes the output to `output_filename`.
    """
    # Read the entire input file into a string, then split into tokens
    with open(input_filename, "r") as f:
        data = f.read().strip().split()
    
    # Create and run the game simulation
    game = GreenRevolutionGame(data)
    game.run()
    
    # Save the purchase decisions to output
    game.write_output(output_filename)


if __name__ == "__main__":
    # Example usage:
    # python solver.py  (it will read from "input.txt" and write to "output.txt")
    solve("./inputs/1-thunberg.txt", "./outputs/1-output.txt")

# %% [markdown]
# # Optuna

# %%
import optuna

class Resource:
    def __init__(self, RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr):
        self.RI = RIr
        self.RA = RAr
        self.RP = RPr
        self.RW = RWr
        self.RM = RMr
        self.RL = RLr
        self.RU = RUr
        self.RT = RTr
        self.RE = REr

class Turn:
    def __init__(self, TM, TX, TR):
        self.TM = TM
        self.TX = TX
        self.TR = TR

class PurchasedResource:
    def __init__(self, resource_index, life_left, active_left, downtime_left):
        self.resource_index = resource_index
        self.life_left = life_left
        self.active_left = active_left
        self.downtime_left = downtime_left

class GreenRevolutionGame:
    def __init__(self, data_tokens):
        self.parse_input(data_tokens)
        self.budget = self.D
        self.purchased_resources = []
        self.output_lines = []
        self.total_profit = 0

    def parse_input(self, data):
        idx = 0
        self.D = int(data[idx]); idx += 1
        self.R = int(data[idx]); idx += 1
        self.T = int(data[idx]); idx += 1

        self.resources = []
        for _ in range(self.R):
            RIr = int(data[idx]); idx += 1
            RAr = int(data[idx]); idx += 1
            RPr = int(data[idx]); idx += 1
            RWr = int(data[idx]); idx += 1
            RMr = int(data[idx]); idx += 1
            RLr = int(data[idx]); idx += 1
            RUr = int(data[idx]); idx += 1
            RTr = data[idx];      idx += 1
            if RTr in ['A','B','C','D','E']:
                REr = int(data[idx]); idx += 1
            else:
                REr = 0

            self.resources.append(Resource(RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr))

        self.turns = []
        for _ in range(self.T):
            TMt = int(data[idx]); idx += 1
            TXt = int(data[idx]); idx += 1
            TRt = int(data[idx]); idx += 1
            self.turns.append(Turn(TMt, TXt, TRt))

    def run_with_plan(self, purchase_plan):
        self.budget = self.D
        self.purchased_resources.clear()
        self.output_lines.clear()
        self.total_profit = 0

        for turn_idx in range(self.T):
            turn_data = self.turns[turn_idx]
            chosen = purchase_plan[turn_idx]
            if chosen is not None:
                # If you allow multiple resources in a single turn, 
                # ensure 'chosen' is a list. For now assume single resource or None.
                if not isinstance(chosen, list):
                    chosen = [chosen]
                total_activation_cost = 0
                for resource_idx in chosen:
                    total_activation_cost += self.resources[resource_idx].RA
                if total_activation_cost <= self.budget:
                    self.budget -= total_activation_cost
                    for resource_idx in chosen:
                        r = self.resources[resource_idx]
                        self.purchased_resources.append(
                            PurchasedResource(resource_idx, r.RL, r.RW, 0)
                        )
                    if len(chosen) > 0:
                        line = f"{turn_idx} {len(chosen)}"
                        for resource_idx in chosen:
                            line += f" {self.resources[resource_idx].RI}"
                        self.output_lines.append(line)

            maintenance_cost = 0
            powered_buildings = 0
            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    r_idx = pr.resource_index
                    maintenance_cost += self.resources[r_idx].RP
                    if pr.active_left > 0:
                        powered_buildings += self.resources[r_idx].RU

            self.budget -= maintenance_cost

            if powered_buildings >= turn_data.TM:
                profit = min(powered_buildings, turn_data.TX) * turn_data.TR
            else:
                profit = 0

            self.budget += profit
            self.total_profit += profit

            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    if pr.active_left > 0:
                        pr.active_left -= 1
                        if pr.active_left == 0:
                            r_idx = pr.resource_index
                            pr.downtime_left = self.resources[r_idx].RM
                    else:
                        if pr.downtime_left > 0:
                            pr.downtime_left -= 1
                            if pr.downtime_left == 0:
                                r_idx = pr.resource_index
                                pr.active_left = self.resources[r_idx].RW
                    pr.life_left -= 1
            self.purchased_resources = [p for p in self.purchased_resources if p.life_left > 0]

        return self.total_profit

    def write_output(self, filename):
        with open(filename, "w") as f:
            for line in self.output_lines:
                f.write(line + "\n")


def create_purchase_plan(trial, T, R):
    plan = []
    for turn_idx in range(T):
        choice = trial.suggest_categorical(
            f"buy_turn_{turn_idx}",
            [None] + list(range(R))
        )
        plan.append(choice)
    return plan

def objective(trial, data_tokens):
    game = GreenRevolutionGame(data_tokens)
    plan = create_purchase_plan(trial, T=game.T, R=game.R)
    score = game.run_with_plan(plan)
    return score

def run_optuna_optimization(input_filename="input.txt", n_trials=100):
    # Read input
    with open(input_filename, "r") as f:
        data = f.read().strip().split()

    # Wrap objective
    def optuna_objective(trial):
        return objective(trial, data)

    # Create the study and run
    study = optuna.create_study(direction="maximize")
    study.optimize(optuna_objective, n_trials=n_trials)

    print("Best Value (Score):", study.best_value)
    print("Best Params:", study.best_params)

    # Reconstruct best plan
    game_for_best = GreenRevolutionGame(data)
    best_plan = []
    for t in range(game_for_best.T):
        param_key = f"buy_turn_{t}"
        best_plan.append(study.best_params[param_key])

    final_score = game_for_best.run_with_plan(best_plan)
    game_for_best.write_output("./outputs/output.txt")
    print("Final plan’s score:", final_score)


if __name__ == "__main__":
    run_optuna_optimization("./inputs/0-demo.txt", n_trials=500)
# Out:
# [I 2025-03-12 17:41:58,351] A new study created in memory with name: no-name-8527f9ec-635a-4807-bb48-2b1ecebd69bf
# [I 2025-03-12 17:41:58,359] Trial 0 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 2, 'buy_turn_2': 3, 'buy_turn_3': 2, 'buy_turn_4': 2, 'buy_turn_5': None}. Best is trial 0 with value: 12.0.
# [I 2025-03-12 17:41:58,366] Trial 1 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 2, 'buy_turn_2': 0, 'buy_turn_3': 4, 'buy_turn_4': 0, 'buy_turn_5': 2}. Best is trial 1 with value: 32.0.
# [I 2025-03-12 17:41:58,375] Trial 2 finished with value: 12.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 1, 'buy_turn_4': 3, 'buy_turn_5': None}. Best is trial 1 with value: 32.0.
# [I 2025-03-12 17:41:58,382] Trial 3 finished with value: 23.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': None, 'buy_turn_2': None, 'buy_turn_3': 4, 'buy_turn_4': None, 'buy_turn_5': 4}. Best is trial 1 with value: 32.0.
# [I 2025-03-12 17:41:58,391] Trial 4 finished with value: 47.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': None, 'buy_turn_2': 0, 'buy_turn_3': 2, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 4 with value: 47.0.
# [I 2025-03-12 17:41:58,398] Trial 5 finished with value: 23.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': None, 'buy_turn_2': None, 'buy_turn_3': 2, 'buy_turn_4': 1, 'buy_turn_5': 2}. Best is trial 4 with value: 47.0.
# [I 2025-03-12 17:41:58,405] Trial 6 finished with value: 12.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 0, 'buy_turn_2': 2, 'buy_turn_3': 1, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 4 with value: 47.0.
# [I 2025-03-12 17:41:58,413] Trial 7 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 2, 'buy_turn_2': 3, 'buy_turn_3': 4, 'buy_turn_4': 1, 'buy_turn_5': None}. Best is trial 4 with value: 47.0.
# [I 2025-03-12 17:41:58,426] Trial 8 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 4, 'buy_turn_3': 3, 'buy_turn_4': 1, 'buy_turn_5': None}. Best is trial 4 with value: 47.0.
# [I 2025-03-12 17:41:58,433] Trial 9 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 0, 'buy_turn_2': 2, 'buy_turn_3': None, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 4 with value: 47.0.
# [I 2025-03-12 17:41:58,451] Trial 10 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,467] Trial 11 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,497] Trial 12 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,512] Trial 13 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,531] Trial 14 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,552] Trial 15 finished with value: 58.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': None, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,563] Trial 16 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,581] Trial 17 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 4, 'buy_turn_3': None, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,596] Trial 18 finished with value: 12.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': 4}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,612] Trial 19 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,629] Trial 20 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,645] Trial 21 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,664] Trial 22 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,684] Trial 23 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,699] Trial 24 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,712] Trial 25 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,732] Trial 26 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 1, 'buy_turn_2': 4, 'buy_turn_3': 1, 'buy_turn_4': None, 'buy_turn_5': 3}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,765] Trial 27 finished with value: 0.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 0, 'buy_turn_2': None, 'buy_turn_3': 3, 'buy_turn_4': 0, 'buy_turn_5': 2}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,790] Trial 28 finished with value: 12.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 4, 'buy_turn_2': 2, 'buy_turn_3': None, 'buy_turn_4': 2, 'buy_turn_5': 1}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,807] Trial 29 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 2, 'buy_turn_2': 3, 'buy_turn_3': 2, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,823] Trial 30 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,842] Trial 31 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,862] Trial 32 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,881] Trial 33 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,898] Trial 34 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 2, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': 0, 'buy_turn_5': 2}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,918] Trial 35 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,939] Trial 36 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': None, 'buy_turn_2': 0, 'buy_turn_3': 1, 'buy_turn_4': 3, 'buy_turn_5': None}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,960] Trial 37 finished with value: 0.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 1, 'buy_turn_2': None, 'buy_turn_3': 2, 'buy_turn_4': 4, 'buy_turn_5': 4}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,979] Trial 38 finished with value: 16.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': None, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:58,996] Trial 39 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,011] Trial 40 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 3, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,027] Trial 41 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,040] Trial 42 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,055] Trial 43 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,068] Trial 44 finished with value: 32.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': None}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,083] Trial 45 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 2, 'buy_turn_2': 4, 'buy_turn_3': None, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,098] Trial 46 finished with value: 12.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 4, 'buy_turn_2': 0, 'buy_turn_3': 1, 'buy_turn_4': 4, 'buy_turn_5': 2}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,115] Trial 47 finished with value: 0.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 3, 'buy_turn_2': None, 'buy_turn_3': 2, 'buy_turn_4': 2, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,131] Trial 48 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,146] Trial 49 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': 3, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,158] Trial 50 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': None, 'buy_turn_5': 4}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,174] Trial 51 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,189] Trial 52 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,205] Trial 53 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,220] Trial 54 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,237] Trial 55 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 3}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,250] Trial 56 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 4, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,263] Trial 57 finished with value: 32.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,280] Trial 58 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': None, 'buy_turn_4': 1, 'buy_turn_5': None}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,295] Trial 59 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,312] Trial 60 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,328] Trial 61 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,345] Trial 62 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,363] Trial 63 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,381] Trial 64 finished with value: 28.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 1, 'buy_turn_4': 4, 'buy_turn_5': 2}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,399] Trial 65 finished with value: 0.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 2, 'buy_turn_2': None, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,424] Trial 66 finished with value: 16.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 2, 'buy_turn_4': 3, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,444] Trial 67 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 3, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,475] Trial 68 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': None, 'buy_turn_5': 4}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,511] Trial 69 finished with value: 16.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,547] Trial 70 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,578] Trial 71 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,626] Trial 72 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,676] Trial 73 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,701] Trial 74 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 4, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': 3}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,722] Trial 75 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 3, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,755] Trial 76 finished with value: 12.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': None}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,784] Trial 77 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,811] Trial 78 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 2}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,836] Trial 79 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 2, 'buy_turn_2': None, 'buy_turn_3': 1, 'buy_turn_4': 2, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,865] Trial 80 finished with value: 62.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,905] Trial 81 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,928] Trial 82 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,957] Trial 83 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:41:59,980] Trial 84 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,003] Trial 85 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 2, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,025] Trial 86 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 2, 'buy_turn_3': 4, 'buy_turn_4': None, 'buy_turn_5': 4}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,043] Trial 87 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,063] Trial 88 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,084] Trial 89 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,106] Trial 90 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 4, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': 3}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,128] Trial 91 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,150] Trial 92 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,170] Trial 93 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,190] Trial 94 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,211] Trial 95 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 4, 'buy_turn_2': 3, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,236] Trial 96 finished with value: 62.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,259] Trial 97 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': None}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,279] Trial 98 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 2}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,300] Trial 99 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 2, 'buy_turn_2': None, 'buy_turn_3': 1, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,323] Trial 100 finished with value: 62.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,351] Trial 101 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,373] Trial 102 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,392] Trial 103 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,413] Trial 104 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,436] Trial 105 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 0, 'buy_turn_3': 2, 'buy_turn_4': 0, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,456] Trial 106 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,484] Trial 107 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': None, 'buy_turn_5': 4}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,506] Trial 108 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': None, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,533] Trial 109 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,554] Trial 110 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,575] Trial 111 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,597] Trial 112 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,610] Trial 113 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,633] Trial 114 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,662] Trial 115 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 4, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': 3}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,690] Trial 116 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,719] Trial 117 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 4, 'buy_turn_2': 3, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': None}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,750] Trial 118 finished with value: 62.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,792] Trial 119 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,828] Trial 120 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 2}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,860] Trial 121 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,885] Trial 122 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,910] Trial 123 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,933] Trial 124 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,958] Trial 125 finished with value: 28.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 2, 'buy_turn_2': 1, 'buy_turn_3': 1, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:00,985] Trial 126 finished with value: 0.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,011] Trial 127 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': None, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,040] Trial 128 finished with value: 16.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 2, 'buy_turn_4': 3, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,063] Trial 129 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 4}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,082] Trial 130 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': None, 'buy_turn_2': 2, 'buy_turn_3': 4, 'buy_turn_4': None, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,097] Trial 131 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,122] Trial 132 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,143] Trial 133 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,163] Trial 134 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,184] Trial 135 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,204] Trial 136 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,228] Trial 137 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,256] Trial 138 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 4, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 3}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,279] Trial 139 finished with value: 32.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,303] Trial 140 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,326] Trial 141 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,349] Trial 142 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,368] Trial 143 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,387] Trial 144 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,409] Trial 145 finished with value: 12.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 4, 'buy_turn_2': 3, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,433] Trial 146 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,460] Trial 147 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': None}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,489] Trial 148 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 2}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,514] Trial 149 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 2, 'buy_turn_2': None, 'buy_turn_3': 1, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,530] Trial 150 finished with value: 62.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,552] Trial 151 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,573] Trial 152 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,594] Trial 153 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,616] Trial 154 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,631] Trial 155 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,651] Trial 156 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,666] Trial 157 finished with value: 16.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 2, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,686] Trial 158 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 4}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,706] Trial 159 finished with value: 16.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': None, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,727] Trial 160 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 0, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,751] Trial 161 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,773] Trial 162 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,798] Trial 163 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,818] Trial 164 finished with value: 62.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 0}. Best is trial 10 with value: 62.0.
# [I 2025-03-12 17:42:01,839] Trial 165 finished with value: 64.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 0}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:01,862] Trial 166 finished with value: 64.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:01,881] Trial 167 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:01,899] Trial 168 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:01,924] Trial 169 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:01,954] Trial 170 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:01,985] Trial 171 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,015] Trial 172 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,045] Trial 173 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,077] Trial 174 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,106] Trial 175 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,136] Trial 176 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,166] Trial 177 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,196] Trial 178 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,224] Trial 179 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,262] Trial 180 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,300] Trial 181 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,317] Trial 182 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,341] Trial 183 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,361] Trial 184 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,385] Trial 185 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,405] Trial 186 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,425] Trial 187 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,445] Trial 188 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,467] Trial 189 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,486] Trial 190 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,508] Trial 191 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,529] Trial 192 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,551] Trial 193 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,584] Trial 194 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,607] Trial 195 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,626] Trial 196 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,648] Trial 197 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,672] Trial 198 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,696] Trial 199 finished with value: 32.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,717] Trial 200 finished with value: 12.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 4, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,739] Trial 201 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,763] Trial 202 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,786] Trial 203 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,806] Trial 204 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,828] Trial 205 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,851] Trial 206 finished with value: 22.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': None, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,874] Trial 207 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,894] Trial 208 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,916] Trial 209 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,938] Trial 210 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,959] Trial 211 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:02,981] Trial 212 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:03,007] Trial 213 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:03,044] Trial 214 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# [I 2025-03-12 17:42:03,092] Trial 215 finished with value: 64.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 165 with value: 64.0.
# ...
# [I 2025-03-12 17:42:09,400] Trial 429 finished with value: 0.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,437] Trial 430 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,475] Trial 431 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,544] Trial 432 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,587] Trial 433 finished with value: 30.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,630] Trial 434 finished with value: 87.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 1, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,653] Trial 435 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 2}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,683] Trial 436 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,712] Trial 437 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,735] Trial 438 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,775] Trial 439 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,805] Trial 440 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,832] Trial 441 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 2, 'buy_turn_3': 2, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,862] Trial 442 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': None, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,887] Trial 443 finished with value: 47.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 4, 'buy_turn_4': 2, 'buy_turn_5': 2}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,916] Trial 444 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,945] Trial 445 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': None}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:09,969] Trial 446 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:10,000] Trial 447 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': None}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:10,030] Trial 448 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:10,056] Trial 449 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': None}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:10,084] Trial 450 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:10,109] Trial 451 finished with value: 0.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 4, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': None}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:10,141] Trial 452 finished with value: 20.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 3, 'buy_turn_3': 3, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:10,169] Trial 453 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': None}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:10,198] Trial 454 finished with value: 93.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 339 with value: 93.0.
# [I 2025-03-12 17:42:10,231] Trial 455 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,258] Trial 456 finished with value: 0.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': None}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,293] Trial 457 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,324] Trial 458 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 2}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,354] Trial 459 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,379] Trial 460 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,411] Trial 461 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,442] Trial 462 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,471] Trial 463 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 1, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,501] Trial 464 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,527] Trial 465 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,558] Trial 466 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,588] Trial 467 finished with value: 68.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,614] Trial 468 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 2, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,646] Trial 469 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,673] Trial 470 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,704] Trial 471 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 4, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,731] Trial 472 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,763] Trial 473 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,807] Trial 474 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,849] Trial 475 finished with value: 68.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 4, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,910] Trial 476 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,953] Trial 477 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:10,994] Trial 478 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,043] Trial 479 finished with value: 59.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,094] Trial 480 finished with value: 0.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,124] Trial 481 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,154] Trial 482 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,183] Trial 483 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 3, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,211] Trial 484 finished with value: 0.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,245] Trial 485 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,275] Trial 486 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,306] Trial 487 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,333] Trial 488 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,360] Trial 489 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,392] Trial 490 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,432] Trial 491 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,467] Trial 492 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,495] Trial 493 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,527] Trial 494 finished with value: 68.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,556] Trial 495 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 1, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,583] Trial 496 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,612] Trial 497 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,644] Trial 498 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# [I 2025-03-12 17:42:11,672] Trial 499 finished with value: 107.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 455 with value: 107.0.
# Best Value (Score): 107.0
# Best Params: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}
# Final plan’s score: 107
