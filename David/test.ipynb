# %%
import sys

class Resource:
    """
    Represents a single resource definition (from the R lines in input).
    """
    def __init__(self, RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr):
        self.RI = RIr  # Resource ID
        self.RA = RAr  # Activation cost
        self.RP = RPr  # Periodic (maintenance) cost
        self.RW = RWr  # Number of consecutive active turns
        self.RM = RMr  # Number of downtime turns required after active cycle
        self.RL = RLr  # Total life in turns
        self.RU = RUr  # Buildings powered when active
        self.RT = RTr  # Special effect type
        self.RE = REr  # Special effect percentage or capacity

class Turn:
    """
    Represents a single turn's constraints: min building (TM), max building (TX), profit per building (TR).
    """
    def __init__(self, TM, TX, TR):
        self.TM = TM
        self.TX = TX
        self.TR = TR

class PurchasedResource:
    """
    Represents a resource instance that has been purchased, tracking where it is in its
    active/downtime life cycle.
    """
    def __init__(self, resource_index, life_left, active_left, downtime_left):
        self.resource_index = resource_index  # index into the 'resources' list
        self.life_left = life_left
        self.active_left = active_left
        self.downtime_left = downtime_left

class GreenRevolutionGame:
    """
    Manages all data (budget, resources, turns), runs the simulation turn by turn,
    and decides which resources to purchase (naively).
    """
    def __init__(self, data):
        # data is the list of tokens read from input
        self.parse_input(data)
        self.budget = self.D
        self.purchased_resources = []  # list of PurchasedResource
        self.output_lines = []         # lines to write into output.txt

    def parse_input(self, data):
        idx = 0
        # First line: D, R, T
        self.D = int(data[idx]); idx += 1
        self.R = int(data[idx]); idx += 1
        self.T = int(data[idx]); idx += 1

        self.resources = []
        for _ in range(self.R):
            RIr = int(data[idx]); idx += 1
            RAr = int(data[idx]); idx += 1
            RPr = int(data[idx]); idx += 1
            RWr = int(data[idx]); idx += 1
            RMr = int(data[idx]); idx += 1
            RLr = int(data[idx]); idx += 1
            RUr = int(data[idx]); idx += 1

            RTr = data[idx];      idx += 1
            if RTr in ['A', 'B', 'C', 'D', 'E']:
                REr = int(data[idx])
                idx += 1
            else:
                REr = 0

            self.resources.append(Resource(RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr))

        self.turns = []
        for _ in range(self.T):
            TMt = int(data[idx]); idx += 1
            TXt = int(data[idx]); idx += 1
            TRt = int(data[idx]); idx += 1
            self.turns.append(Turn(TMt, TXt, TRt))

    def decide_which_resource_to_buy(self):
        """
        Naive: picks a single resource with the best RU/(RA+RP) ratio,
        if affordable. Returns its index in self.resources, or None if none is affordable.
        """
        best_idx = None
        best_score = -1.0

        for i, r in enumerate(self.resources):
            if r.RA <= self.budget:
                cost = float(r.RA + r.RP) if (r.RP > 0) else float(r.RA)
                ratio = float(r.RU) / cost if cost > 0 else r.RU
                if ratio > best_score:
                    best_score = ratio
                    best_idx = i
        return best_idx

    def run(self):
        """
        Simulate the T turns. On each turn:
          1) Possibly buy resources (if affordable).
          2) Pay maintenance costs.
          3) Compute powered buildings, check if >= TM => compute profit.
          4) Update budget, reduce lifecycles, remove obsolete resources.
        """
        for turn_idx in range(self.T):
            turn_data = self.turns[turn_idx]

            # -- 1) Purchase Phase (naive) --
            chosen_idx = self.decide_which_resource_to_buy()
            if chosen_idx is not None:
                cost_needed = self.resources[chosen_idx].RA
                if cost_needed <= self.budget:
                    # Buy this resource
                    self.budget -= cost_needed
                    r = self.resources[chosen_idx]
                    # Add a new purchased resource
                    self.purchased_resources.append(
                        PurchasedResource(
                            resource_index=chosen_idx,
                            life_left=r.RL,
                            active_left=r.RW,
                            downtime_left=0
                        )
                    )
                    # Record in output
                    line = f"{turn_idx} 1 {r.RI}"
                    self.output_lines.append(line)

            # -- 2) Pay maintenance + track total powered buildings --
            maintenance_cost = 0
            powered_buildings = 0

            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    # Maintenance cost
                    r_idx = pr.resource_index
                    maintenance_cost += self.resources[r_idx].RP
                    # If in active phase, add RU
                    if pr.active_left > 0:
                        powered_buildings += self.resources[r_idx].RU

            # Subtract maintenance cost from budget
            self.budget -= maintenance_cost

            # -- 3) Compute profit (if TM is met) --
            if powered_buildings >= turn_data.TM:
                profit = min(powered_buildings, turn_data.TX) * turn_data.TR
            else:
                profit = 0

            # Update budget
            self.budget += profit

            # -- 4) Decrement resource lifecycles --
            new_purchases = []
            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    # If active
                    if pr.active_left > 0:
                        pr.active_left -= 1
                        # If just ended active phase, set downtime
                        if pr.active_left == 0:
                            r_idx = pr.resource_index
                            pr.downtime_left = self.resources[r_idx].RM
                    else:
                        # In downtime
                        if pr.downtime_left > 0:
                            pr.downtime_left -= 1
                            if pr.downtime_left == 0:
                                r_idx = pr.resource_index
                                pr.active_left = self.resources[r_idx].RW

                    pr.life_left -= 1

            # Remove dead resources
            self.purchased_resources = [
                pr for pr in self.purchased_resources if pr.life_left > 0
            ]

    def write_output(self, filename="output.txt"):
        """
        Writes the recorded purchase lines to output.txt (or another file).
        Each line is "turn Rcount RI1 RI2 ..."
        (Here, we always buy at most 1 resource, so Rcount=1 or 0.)
        """
        with open(filename, "w") as f:
            for line in self.output_lines:
                f.write(line + "\n")

def solve():
    # Read data from stdin
    data = sys.stdin.read().strip().split()

    # Create a game instance
    game = GreenRevolutionGame(data)
    # Run the simulation
    game.run()
    # Write all purchases to "output.txt"
    game.write_output("output.txt")

# %%
class Resource:
    """
    Represents a single resource definition (from the R lines in input).
    """
    def __init__(self, RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr):
        self.RI = RIr  # Resource ID
        self.RA = RAr  # Activation cost
        self.RP = RPr  # Periodic (maintenance) cost
        self.RW = RWr  # Number of consecutive active turns
        self.RM = RMr  # Number of downtime turns required after active cycle
        self.RL = RLr  # Total life in turns
        self.RU = RUr  # Buildings powered when active
        self.RT = RTr  # Special effect type
        self.RE = REr  # Special effect parameter (percentage or capacity)


class Turn:
    """
    Represents a single turn's constraints: min building (TM), max building (TX), profit per building (TR).
    """
    def __init__(self, TM, TX, TR):
        self.TM = TM
        self.TX = TX
        self.TR = TR


class PurchasedResource:
    """
    Represents a resource instance that has been purchased, tracking where it is in its
    active/downtime life cycle.
    """
    def __init__(self, resource_index, life_left, active_left, downtime_left):
        self.resource_index = resource_index  # index into the 'resources' list
        self.life_left = life_left
        self.active_left = active_left
        self.downtime_left = downtime_left


class GreenRevolutionGame:
    """
    Manages all data (budget, resources, turns), runs the simulation turn by turn,
    and decides which resources to purchase (naively).
    """
    def __init__(self, data_tokens):
        # Parse the data from a list of tokens (strings).
        self.parse_input(data_tokens)
        self.budget = self.D
        self.purchased_resources = []  # list of PurchasedResource
        self.output_lines = []         # lines to write into output file

    def parse_input(self, data):
        idx = 0
        # First line: D, R, T
        self.D = int(data[idx]); idx += 1
        self.R = int(data[idx]); idx += 1
        self.T = int(data[idx]); idx += 1

        self.resources = []
        for _ in range(self.R):
            RIr = int(data[idx]); idx += 1
            RAr = int(data[idx]); idx += 1
            RPr = int(data[idx]); idx += 1
            RWr = int(data[idx]); idx += 1
            RMr = int(data[idx]); idx += 1
            RLr = int(data[idx]); idx += 1
            RUr = int(data[idx]); idx += 1

            RTr = data[idx];      idx += 1
            if RTr in ['A', 'B', 'C', 'D', 'E']:
                REr = int(data[idx])
                idx += 1
            else:
                REr = 0

            self.resources.append(Resource(RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr))

        self.turns = []
        for _ in range(self.T):
            TMt = int(data[idx]); idx += 1
            TXt = int(data[idx]); idx += 1
            TRt = int(data[idx]); idx += 1
            self.turns.append(Turn(TMt, TXt, TRt))

    def decide_which_resource_to_buy(self):
        """
        Naive: picks a single resource with the best RU/(RA+RP) ratio,
        if affordable. Returns its index in self.resources, or None if no resource is affordable.
        """
        best_idx = None
        best_score = -1.0

        for i, r in enumerate(self.resources):
            if r.RA <= self.budget:
                cost = float(r.RA + r.RP) if (r.RP > 0) else float(r.RA)
                ratio = float(r.RU) / cost if cost > 0 else r.RU
                if ratio > best_score:
                    best_score = ratio
                    best_idx = i
        return best_idx

    def run(self):
        """
        Simulate T turns. On each turn:
          1) Possibly buy resources (if affordable).
          2) Pay maintenance costs.
          3) Compute powered buildings, check if >= TM => compute profit.
          4) Update budget, reduce lifecycles, remove obsolete resources.
        """
        for turn_idx in range(self.T):
            turn_data = self.turns[turn_idx]

            # -- 1) Purchase Phase (naive) --
            chosen_idx = self.decide_which_resource_to_buy()
            if chosen_idx is not None:
                cost_needed = self.resources[chosen_idx].RA
                if cost_needed <= self.budget:
                    # Buy this resource
                    self.budget -= cost_needed
                    r = self.resources[chosen_idx]
                    # Add a new purchased resource
                    self.purchased_resources.append(
                        PurchasedResource(
                            resource_index=chosen_idx,
                            life_left=r.RL,
                            active_left=r.RW,
                            downtime_left=0
                        )
                    )
                    # Record purchase in output (turn, count=1, resourceID)
                    line = f"{turn_idx} 1 {r.RI}"
                    self.output_lines.append(line)

            # -- 2) Pay maintenance + track total powered buildings --
            maintenance_cost = 0
            powered_buildings = 0

            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    # Maintenance cost
                    r_idx = pr.resource_index
                    maintenance_cost += self.resources[r_idx].RP
                    # If in active phase, add RU
                    if pr.active_left > 0:
                        powered_buildings += self.resources[r_idx].RU

            # Subtract maintenance cost from budget
            self.budget -= maintenance_cost

            # -- 3) Compute profit (if TM is met) --
            if powered_buildings >= turn_data.TM:
                profit = min(powered_buildings, turn_data.TX) * turn_data.TR
            else:
                profit = 0

            # Update budget
            self.budget += profit

            # -- 4) Decrement resource lifecycles --
            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    # If active
                    if pr.active_left > 0:
                        pr.active_left -= 1
                        # If just ended active phase, set downtime
                        if pr.active_left == 0:
                            r_idx = pr.resource_index
                            pr.downtime_left = self.resources[r_idx].RM
                    else:
                        # In downtime
                        if pr.downtime_left > 0:
                            pr.downtime_left -= 1
                            if pr.downtime_left == 0:
                                r_idx = pr.resource_index
                                pr.active_left = self.resources[r_idx].RW

                    # Decrease total life
                    pr.life_left -= 1

            # Remove dead resources
            self.purchased_resources = [pr for pr in self.purchased_resources if pr.life_left > 0]

    def write_output(self, filename):
        """
        Writes the recorded purchase lines to the given file.
        Each line is "turn Rcount RI1 RI2 ...".
        """
        with open(filename, "w") as f:
            for line in self.output_lines:
                f.write(line + "\n")


def solve(input_filename="0-demo.txt", output_filename="output.txt"):
    """
    Reads all tokens from `input_filename`, runs the naive solver,
    and writes the output to `output_filename`.
    """
    # Read the entire input file into a string, then split into tokens
    with open(input_filename, "r") as f:
        data = f.read().strip().split()
    
    # Create and run the game simulation
    game = GreenRevolutionGame(data)
    game.run()
    
    # Save the purchase decisions to output
    game.write_output(output_filename)


if __name__ == "__main__":
    # Example usage:
    # python solver.py  (it will read from "input.txt" and write to "output.txt")
    solve("./inputs/1-thunberg.txt", "./outputs/1-output.txt")

# %%
import optuna

class Resource:
    def __init__(self, RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr):
        self.RI = RIr
        self.RA = RAr
        self.RP = RPr
        self.RW = RWr
        self.RM = RMr
        self.RL = RLr
        self.RU = RUr
        self.RT = RTr
        self.RE = REr

class Turn:
    def __init__(self, TM, TX, TR):
        self.TM = TM
        self.TX = TX
        self.TR = TR

class PurchasedResource:
    def __init__(self, resource_index, life_left, active_left, downtime_left):
        self.resource_index = resource_index
        self.life_left = life_left
        self.active_left = active_left
        self.downtime_left = downtime_left

class GreenRevolutionGame:
    def __init__(self, data_tokens):
        self.parse_input(data_tokens)
        self.budget = self.D
        self.purchased_resources = []
        self.output_lines = []
        self.total_profit = 0

    def parse_input(self, data):
        idx = 0
        self.D = int(data[idx]); idx += 1
        self.R = int(data[idx]); idx += 1
        self.T = int(data[idx]); idx += 1

        self.resources = []
        for _ in range(self.R):
            RIr = int(data[idx]); idx += 1
            RAr = int(data[idx]); idx += 1
            RPr = int(data[idx]); idx += 1
            RWr = int(data[idx]); idx += 1
            RMr = int(data[idx]); idx += 1
            RLr = int(data[idx]); idx += 1
            RUr = int(data[idx]); idx += 1
            RTr = data[idx];      idx += 1
            if RTr in ['A','B','C','D','E']:
                REr = int(data[idx]); idx += 1
            else:
                REr = 0

            self.resources.append(Resource(RIr, RAr, RPr, RWr, RMr, RLr, RUr, RTr, REr))

        self.turns = []
        for _ in range(self.T):
            TMt = int(data[idx]); idx += 1
            TXt = int(data[idx]); idx += 1
            TRt = int(data[idx]); idx += 1
            self.turns.append(Turn(TMt, TXt, TRt))

    def run_with_plan(self, purchase_plan):
        self.budget = self.D
        self.purchased_resources.clear()
        self.output_lines.clear()
        self.total_profit = 0

        for turn_idx in range(self.T):
            turn_data = self.turns[turn_idx]
            chosen = purchase_plan[turn_idx]
            if chosen is not None:
                # If you allow multiple resources in a single turn, 
                # ensure 'chosen' is a list. For now assume single resource or None.
                if not isinstance(chosen, list):
                    chosen = [chosen]
                total_activation_cost = 0
                for resource_idx in chosen:
                    total_activation_cost += self.resources[resource_idx].RA
                if total_activation_cost <= self.budget:
                    self.budget -= total_activation_cost
                    for resource_idx in chosen:
                        r = self.resources[resource_idx]
                        self.purchased_resources.append(
                            PurchasedResource(resource_idx, r.RL, r.RW, 0)
                        )
                    if len(chosen) > 0:
                        line = f"{turn_idx} {len(chosen)}"
                        for resource_idx in chosen:
                            line += f" {self.resources[resource_idx].RI}"
                        self.output_lines.append(line)

            maintenance_cost = 0
            powered_buildings = 0
            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    r_idx = pr.resource_index
                    maintenance_cost += self.resources[r_idx].RP
                    if pr.active_left > 0:
                        powered_buildings += self.resources[r_idx].RU

            self.budget -= maintenance_cost

            if powered_buildings >= turn_data.TM:
                profit = min(powered_buildings, turn_data.TX) * turn_data.TR
            else:
                profit = 0

            self.budget += profit
            self.total_profit += profit

            for pr in self.purchased_resources:
                if pr.life_left > 0:
                    if pr.active_left > 0:
                        pr.active_left -= 1
                        if pr.active_left == 0:
                            r_idx = pr.resource_index
                            pr.downtime_left = self.resources[r_idx].RM
                    else:
                        if pr.downtime_left > 0:
                            pr.downtime_left -= 1
                            if pr.downtime_left == 0:
                                r_idx = pr.resource_index
                                pr.active_left = self.resources[r_idx].RW
                    pr.life_left -= 1
            self.purchased_resources = [p for p in self.purchased_resources if p.life_left > 0]

        return self.total_profit

    def write_output(self, filename):
        with open(filename, "w") as f:
            for line in self.output_lines:
                f.write(line + "\n")


def create_purchase_plan(trial, T, R):
    plan = []
    for turn_idx in range(T):
        choice = trial.suggest_categorical(
            f"buy_turn_{turn_idx}",
            [None] + list(range(R))
        )
        plan.append(choice)
    return plan

def objective(trial, data_tokens):
    game = GreenRevolutionGame(data_tokens)
    plan = create_purchase_plan(trial, T=game.T, R=game.R)
    score = game.run_with_plan(plan)
    return score

def run_optuna_optimization(input_filename="input.txt", n_trials=100):
    # Read input
    with open(input_filename, "r") as f:
        data = f.read().strip().split()

    # Wrap objective
    def optuna_objective(trial):
        return objective(trial, data)

    # Create the study and run
    study = optuna.create_study(direction="maximize")
    study.optimize(optuna_objective, n_trials=n_trials)

    print("Best Value (Score):", study.best_value)
    print("Best Params:", study.best_params)

    # Reconstruct best plan
    game_for_best = GreenRevolutionGame(data)
    best_plan = []
    for t in range(game_for_best.T):
        param_key = f"buy_turn_{t}"
        best_plan.append(study.best_params[param_key])

    final_score = game_for_best.run_with_plan(best_plan)
    game_for_best.write_output("output.txt")
    print("Final plan’s score:", final_score)


if __name__ == "__main__":
    run_optuna_optimization("0-demo.txt", n_trials=500)
# Out:
# [I 2025-03-12 17:28:54,996] A new study created in memory with name: no-name-487c29dd-afa5-4b70-be52-5851b330c8f7
# [I 2025-03-12 17:28:55,002] Trial 0 finished with value: 48.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': None, 'buy_turn_4': 1, 'buy_turn_5': 1}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,006] Trial 1 finished with value: 16.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': 0, 'buy_turn_5': 2}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,010] Trial 2 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 4, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': 2}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,016] Trial 3 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 4, 'buy_turn_2': 3, 'buy_turn_3': 4, 'buy_turn_4': 1, 'buy_turn_5': None}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,020] Trial 4 finished with value: 12.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': None, 'buy_turn_2': 4, 'buy_turn_3': 3, 'buy_turn_4': 0, 'buy_turn_5': 2}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,025] Trial 5 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,031] Trial 6 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': None, 'buy_turn_3': 4, 'buy_turn_4': None, 'buy_turn_5': 2}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,036] Trial 7 finished with value: 4.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 4, 'buy_turn_4': 1, 'buy_turn_5': 0}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,040] Trial 8 finished with value: 12.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 4, 'buy_turn_2': 4, 'buy_turn_3': 4, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,043] Trial 9 finished with value: 30.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 1, 'buy_turn_2': None, 'buy_turn_3': 2, 'buy_turn_4': 2, 'buy_turn_5': None}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,064] Trial 10 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 2, 'buy_turn_2': 2, 'buy_turn_3': None, 'buy_turn_4': 3, 'buy_turn_5': 1}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,079] Trial 11 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 1}. Best is trial 0 with value: 48.0.
# [I 2025-03-12 17:28:55,107] Trial 12 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,122] Trial 13 finished with value: 32.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 1, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,147] Trial 14 finished with value: 44.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,167] Trial 15 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': None, 'buy_turn_5': 1}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,189] Trial 16 finished with value: 0.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 2, 'buy_turn_2': 2, 'buy_turn_3': None, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,205] Trial 17 finished with value: 40.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': None, 'buy_turn_2': 3, 'buy_turn_3': 1, 'buy_turn_4': 1, 'buy_turn_5': 0}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,224] Trial 18 finished with value: 16.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 2, 'buy_turn_4': 1, 'buy_turn_5': 1}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,251] Trial 19 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,267] Trial 20 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,280] Trial 21 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,293] Trial 22 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,309] Trial 23 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,324] Trial 24 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,340] Trial 25 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,365] Trial 26 finished with value: 0.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,398] Trial 27 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': None, 'buy_turn_2': None, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,433] Trial 28 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 2, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,453] Trial 29 finished with value: 44.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': 4}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,471] Trial 30 finished with value: 16.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 2, 'buy_turn_4': None, 'buy_turn_5': 0}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,491] Trial 31 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,511] Trial 32 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,541] Trial 33 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,560] Trial 34 finished with value: 56.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 1, 'buy_turn_4': 2, 'buy_turn_5': None}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,579] Trial 35 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 4, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,608] Trial 36 finished with value: 16.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 2, 'buy_turn_5': 2}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,640] Trial 37 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,671] Trial 38 finished with value: 12.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 4, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': None}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,695] Trial 39 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 4, 'buy_turn_3': 3, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,710] Trial 40 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 4, 'buy_turn_4': 0, 'buy_turn_5': 2}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,729] Trial 41 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,747] Trial 42 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,769] Trial 43 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': None, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,790] Trial 44 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,809] Trial 45 finished with value: 12.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': None, 'buy_turn_5': 0}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,826] Trial 46 finished with value: 16.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 2, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,845] Trial 47 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 2, 'buy_turn_2': 2, 'buy_turn_3': None, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,868] Trial 48 finished with value: 16.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': 2, 'buy_turn_5': None}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,892] Trial 49 finished with value: 42.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 1, 'buy_turn_2': 4, 'buy_turn_3': 1, 'buy_turn_4': 2, 'buy_turn_5': 4}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,921] Trial 50 finished with value: 4.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 0, 'buy_turn_2': None, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 2}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,945] Trial 51 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,969] Trial 52 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:55,983] Trial 53 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:56,006] Trial 54 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 1}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:56,029] Trial 55 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 3, 'buy_turn_2': 3, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:56,048] Trial 56 finished with value: 62.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:56,066] Trial 57 finished with value: 12.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 4, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': None, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:56,083] Trial 58 finished with value: 16.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 2, 'buy_turn_4': 3, 'buy_turn_5': 0}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:56,100] Trial 59 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 2, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:56,120] Trial 60 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': 2, 'buy_turn_5': 1}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:56,141] Trial 61 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:56,155] Trial 62 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:56,173] Trial 63 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 2, 'buy_turn_5': 3}. Best is trial 12 with value: 62.0.
# [I 2025-03-12 17:28:56,189] Trial 64 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,208] Trial 65 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,225] Trial 66 finished with value: 32.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 1, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,246] Trial 67 finished with value: 50.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,268] Trial 68 finished with value: 4.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 4}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,284] Trial 69 finished with value: 4.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 1, 'buy_turn_2': None, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,301] Trial 70 finished with value: 20.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': None, 'buy_turn_4': 1, 'buy_turn_5': None}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,322] Trial 71 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,339] Trial 72 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,356] Trial 73 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,378] Trial 74 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,401] Trial 75 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,424] Trial 76 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,441] Trial 77 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,457] Trial 78 finished with value: 4.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 2}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,474] Trial 79 finished with value: 4.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 4, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,491] Trial 80 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,508] Trial 81 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,527] Trial 82 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,546] Trial 83 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,566] Trial 84 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,640] Trial 85 finished with value: 16.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 2, 'buy_turn_4': 1, 'buy_turn_5': 0}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,652] Trial 86 finished with value: 4.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,667] Trial 87 finished with value: 51.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 1, 'buy_turn_5': 1}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,687] Trial 88 finished with value: 32.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 1, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,711] Trial 89 finished with value: 16.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,730] Trial 90 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 2, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,754] Trial 91 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,768] Trial 92 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,788] Trial 93 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,818] Trial 94 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,845] Trial 95 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,861] Trial 96 finished with value: 4.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': None, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': None}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,880] Trial 97 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 4}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,905] Trial 98 finished with value: 4.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 4, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,924] Trial 99 finished with value: 16.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': None, 'buy_turn_4': 0, 'buy_turn_5': 2}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,942] Trial 100 finished with value: 66.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,967] Trial 101 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:56,991] Trial 102 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,014] Trial 103 finished with value: 4.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,035] Trial 104 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 0, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,054] Trial 105 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,096] Trial 106 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,128] Trial 107 finished with value: 16.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 1, 'buy_turn_3': 2, 'buy_turn_4': None, 'buy_turn_5': 0}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,160] Trial 108 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,188] Trial 109 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,218] Trial 110 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 2, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': 1, 'buy_turn_5': 1}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,239] Trial 111 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,284] Trial 112 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,306] Trial 113 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,326] Trial 114 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,343] Trial 115 finished with value: 32.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 1, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,366] Trial 116 finished with value: 12.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,389] Trial 117 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,410] Trial 118 finished with value: 50.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,432] Trial 119 finished with value: 4.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': None, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 4}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,452] Trial 120 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': None}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,474] Trial 121 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,505] Trial 122 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,530] Trial 123 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,554] Trial 124 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,579] Trial 125 finished with value: 4.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,607] Trial 126 finished with value: 12.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 4, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,630] Trial 127 finished with value: 20.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': None, 'buy_turn_4': 1, 'buy_turn_5': 2}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,656] Trial 128 finished with value: 62.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': None, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,678] Trial 129 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': None, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,705] Trial 130 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,728] Trial 131 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,747] Trial 132 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,770] Trial 133 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,788] Trial 134 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,812] Trial 135 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 0}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,830] Trial 136 finished with value: 4.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 2, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,854] Trial 137 finished with value: 16.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 2, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,877] Trial 138 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 2, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': 1, 'buy_turn_5': 1}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,898] Trial 139 finished with value: 12.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,917] Trial 140 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,938] Trial 141 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,964] Trial 142 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:57,990] Trial 143 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,014] Trial 144 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,038] Trial 145 finished with value: 32.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 1, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,066] Trial 146 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,089] Trial 147 finished with value: 50.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,107] Trial 148 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 4}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,124] Trial 149 finished with value: 0.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': None, 'buy_turn_3': 0, 'buy_turn_4': 4, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,140] Trial 150 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': None}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,165] Trial 151 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,188] Trial 152 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,212] Trial 153 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,233] Trial 154 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,253] Trial 155 finished with value: 12.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 0, 'buy_turn_2': 4, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,272] Trial 156 finished with value: 16.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': None, 'buy_turn_4': None, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,289] Trial 157 finished with value: 4.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,311] Trial 158 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 3, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,331] Trial 159 finished with value: 4.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': None, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,350] Trial 160 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,372] Trial 161 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 2}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,397] Trial 162 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,418] Trial 163 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,441] Trial 164 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,471] Trial 165 finished with value: 66.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,490] Trial 166 finished with value: 66.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 0}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,516] Trial 167 finished with value: 4.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 1, 'buy_turn_2': 2, 'buy_turn_3': 2, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,536] Trial 168 finished with value: 62.0 and parameters: {'buy_turn_0': 0, 'buy_turn_1': 2, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 1, 'buy_turn_5': 3}. Best is trial 64 with value: 66.0.
# [I 2025-03-12 17:28:58,557] Trial 169 finished with value: 85.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 169 with value: 85.0.
# [I 2025-03-12 17:28:58,580] Trial 170 finished with value: 39.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 4, 'buy_turn_4': 0, 'buy_turn_5': 1}. Best is trial 169 with value: 85.0.
# [I 2025-03-12 17:28:58,603] Trial 171 finished with value: 85.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 169 with value: 85.0.
# [I 2025-03-12 17:28:58,631] Trial 172 finished with value: 85.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 169 with value: 85.0.
# [I 2025-03-12 17:28:58,658] Trial 173 finished with value: 85.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 169 with value: 85.0.
# [I 2025-03-12 17:28:58,682] Trial 174 finished with value: 85.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 169 with value: 85.0.
# [I 2025-03-12 17:28:58,714] Trial 175 finished with value: 85.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 1, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 169 with value: 85.0.
# [I 2025-03-12 17:28:58,737] Trial 176 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:58,759] Trial 177 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:58,786] Trial 178 finished with value: 48.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 3, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:58,811] Trial 179 finished with value: 60.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 1, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:58,829] Trial 180 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:58,855] Trial 181 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:58,878] Trial 182 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:58,900] Trial 183 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:58,921] Trial 184 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:58,948] Trial 185 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:58,968] Trial 186 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:58,990] Trial 187 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,007] Trial 188 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,028] Trial 189 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,048] Trial 190 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,068] Trial 191 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,090] Trial 192 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,115] Trial 193 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,140] Trial 194 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,164] Trial 195 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,186] Trial 196 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 3}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,206] Trial 197 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,235] Trial 198 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': None, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,260] Trial 199 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,285] Trial 200 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,323] Trial 201 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,371] Trial 202 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,426] Trial 203 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,473] Trial 204 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,547] Trial 205 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,574] Trial 206 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 3, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,617] Trial 207 finished with value: 48.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': None, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,660] Trial 208 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,690] Trial 209 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 0, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,716] Trial 210 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,740] Trial 211 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,767] Trial 212 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,791] Trial 213 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 4, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,814] Trial 214 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,837] Trial 215 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,866] Trial 216 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# [I 2025-03-12 17:28:59,886] Trial 217 finished with value: 90.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 4, 'buy_turn_2': 1, 'buy_turn_3': 0, 'buy_turn_4': 0, 'buy_turn_5': 4}. Best is trial 176 with value: 90.0.
# ...
# [I 2025-03-12 17:29:05,983] Trial 430 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,015] Trial 431 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,068] Trial 432 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,138] Trial 433 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,194] Trial 434 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,236] Trial 435 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,266] Trial 436 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,298] Trial 437 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': None, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,325] Trial 438 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 3, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,352] Trial 439 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,383] Trial 440 finished with value: 75.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': None, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,413] Trial 441 finished with value: 0.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,439] Trial 442 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,472] Trial 443 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 4, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,504] Trial 444 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,533] Trial 445 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,567] Trial 446 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,598] Trial 447 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,623] Trial 448 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 2, 'buy_turn_2': 0, 'buy_turn_3': 1, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,652] Trial 449 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,686] Trial 450 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,712] Trial 451 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,746] Trial 452 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,772] Trial 453 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,804] Trial 454 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,832] Trial 455 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 2, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,864] Trial 456 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,892] Trial 457 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,919] Trial 458 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': None}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,954] Trial 459 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:06,996] Trial 460 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 2, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,024] Trial 461 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,060] Trial 462 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 2}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,085] Trial 463 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,118] Trial 464 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': None, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,145] Trial 465 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,176] Trial 466 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,202] Trial 467 finished with value: 0.0 and parameters: {'buy_turn_0': 2, 'buy_turn_1': None, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 3, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,237] Trial 468 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,268] Trial 469 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,293] Trial 470 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,322] Trial 471 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 4, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,355] Trial 472 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,438] Trial 473 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,498] Trial 474 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 1, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,541] Trial 475 finished with value: 36.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 3, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,599] Trial 476 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 2, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,627] Trial 477 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,653] Trial 478 finished with value: 0.0 and parameters: {'buy_turn_0': 3, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,682] Trial 479 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,714] Trial 480 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 2, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,740] Trial 481 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,774] Trial 482 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': None}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,804] Trial 483 finished with value: 68.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 2, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,835] Trial 484 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,868] Trial 485 finished with value: 12.0 and parameters: {'buy_turn_0': 4, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,893] Trial 486 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,926] Trial 487 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 2}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,956] Trial 488 finished with value: 83.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': 2, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:07,990] Trial 489 finished with value: 0.0 and parameters: {'buy_turn_0': None, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': None, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:08,021] Trial 490 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:08,050] Trial 491 finished with value: 47.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': None, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 3, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:08,086] Trial 492 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:08,123] Trial 493 finished with value: 87.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': None, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:08,155] Trial 494 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:08,187] Trial 495 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:08,216] Trial 496 finished with value: 59.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 3, 'buy_turn_3': 4, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:08,250] Trial 497 finished with value: 111.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:08,278] Trial 498 finished with value: 71.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 4, 'buy_turn_3': 3, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# [I 2025-03-12 17:29:08,312] Trial 499 finished with value: 32.0 and parameters: {'buy_turn_0': 1, 'buy_turn_1': 2, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}. Best is trial 346 with value: 111.0.
# Best Value (Score): 111.0
# Best Params: {'buy_turn_0': 1, 'buy_turn_1': 0, 'buy_turn_2': 0, 'buy_turn_3': None, 'buy_turn_4': 4, 'buy_turn_5': 1}
# Final plan’s score: 111
